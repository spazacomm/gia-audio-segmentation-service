# %% [markdown]
# <a href="https://colab.research.google.com/github/spazacomm/gia-audio-segmentation-service/blob/collab-pipelines/gia_v2_audio_segmentation_mvp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
